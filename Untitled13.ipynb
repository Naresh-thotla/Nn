# %%
import os
from bs4 import BeautifulSoup
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv

sad1='/mobiles/samsung~brand/pr?fm=merchandising&iid=M_55568aff-2da2-4230-809c-8c6a180c7620_3.8YU2PLHN2B&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&page=1&sid=tyy%2C4io&viewType=list'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'https://www.flipkart.com'+sad1
    print (url)
    u = urlopen(url)
    try:
        html = u.read().decode('utf-8')
    finally:
        u.close()
    soup = BeautifulSoup(html, "html.parser")
    aa=soup.find('div',{'class':"_2SxMvQ"})
    for link in aa.select('a'):
        sad = link.get('href')
#         print(sad)
        sad4='https://www.flipkart.com'+sad
        n = urlopen(sad4)
        print(sad4)
        try:
            html1 = n.read().decode('utf-8')
        finally:
            n.close()
        soup2 = BeautifulSoup(html1,"html.parser")
        mt=soup2.find('div',{'class':"_1MVZfW"})
        ml=soup2.find('div',{'class':"_2UDlNd"})
        print(mt.text)
    if(soup.find('div',text="Next")):
        an=soup.find('div',text="Next")
        for na in an.select('a'):
            sad1 = na.get('href')
            print(sad1)
# Out:
# https://www.flipkart.com/mobiles/samsung~brand/pr?fm=merchandising&iid=M_55568aff-2da2-4230-809c-8c6a180c7620_3.8YU2PLHN2B&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&page=1&sid=tyy%2C4io&viewType=list
# https://www.flipkart.com/samsung-galaxy-on5-gold-8-gb/p/itmedhx3uy3qsfks?pid=MOBECCA5FHQD43KA&srno=b_1_1&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&lid=LSTMOBECCA5FHQD43KAK2QMJD&iid=70a2fb18-eb7a-4ae1-861b-082fc1096275.MOBECCA5FHQD43KA.SEARCH
# Samsung Galaxy On5 (Gold, 8 GB)  (1.5 GB RAM)4.2 ★99,169 Ratings & 15,296 Reviews₹6,990₹8,99022% off?
# https://www.flipkart.com/samsung-galaxy-j3-pro-gold-16-gb/p/itmeu35jfryetgew?pid=MOBEU35JAZKVWRPV&srno=b_1_2&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&lid=LSTMOBEU35JAZKVWRPVUXDI0L&iid=e6a29b1c-bb92-4f5c-9291-18494a674cc0.MOBEU35JAZKVWRPV.SEARCH
# ...

# %%
import os
from bs4 import BeautifulSoup
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv
# writefile = 'nnnnnn.csv'
# blueb = open(writefile, 'w')
# wr = csv.writer(blueb)
# wr.writerow(["f1","f2","f3","f4","f5","f6","f7","f8","f9"])

sad1='/mobiles/samsung~brand/pr?fm=merchandising&iid=M_55568aff-2da2-4230-809c-8c6a180c7620_3.8YU2PLHN2B&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&page=1&sid=tyy%2C4io&viewType=list'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'https://www.flipkart.com'+sad1
    print (url)
    u = urlopen(url)
    try:
        html = u.read().decode('utf-8')
    finally:
        u.close()
    soup = BeautifulSoup(html, "html.parser")
    aa=soup.find('div',{'class':"_2SxMvQ"})
    for link in aa.select('a'):
        sad = link.get('href')
#         print(sad)
        sad4='https://www.flipkart.com'+sad
        n = urlopen(sad4)
        print(sad4)
#         f1=sad4
        try:
            html1 = n.read().decode('utf-8')
        finally:
            n.close()
        soup2 = BeautifulSoup(html1,"html.parser")
        mt=soup2.find('div',{'class':"_2UDlNd"})
        for items in soup2.find('div',{'class':"_1MVZfW"}):
            print(items.text)
#             f2=items.text
        ab=soup2.find('li',{'class':"_2-riNZ"})
        print(ab.text)
#         f3=ab.text
        for item in ab.find_next_siblings():
            print(item.text)
#             f4=item.text
#         for an in soup2.find('div',{'class':"_1-V7IJ"}):
#             print(an.text)
#             f5=an.text
        ap= soup2.find('li',{'class':"_2ptBxu"})
        print(ap.text)
#         f6=ap.text
        for item in an.find_next_siblings():
            print(item.text)
            f7=item.text
        ad= soup2.find('li',{'class':"_1KuY3T row"})
        print(ad.text)
        f8=ad.text
        for item in ad.find_next_siblings():
            print(item.text)
            f9=item.text
        i=i+1
        print(i)
#         wr.writerow([f1,f2,f3,f4,f5,f6,f7,f8,f9])
# blueb.close()    
# print (json.dumps(celldict))        
#         for items in soup2.find('div',{'class':"n9S0lU flex"}):
#             print(items.text)
#         for items in soup2.find('div',{'class':"_2Kp3n6"}):
#             print(items.text)
#     if(soup.find('div',text="Next")):
#         an=soup.find('div',text="Next")
#         for na in an.select('a'):
#             sad1 = na.get('href')
#             print(sad1)
# Out:
# https://www.flipkart.com/mobiles/samsung~brand/pr?fm=merchandising&iid=M_55568aff-2da2-4230-809c-8c6a180c7620_3.8YU2PLHN2B&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&page=1&sid=tyy%2C4io&viewType=list
# https://www.flipkart.com/samsung-galaxy-on5-gold-8-gb/p/itmedhx3uy3qsfks?pid=MOBECCA5FHQD43KA&srno=b_1_1&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&lid=LSTMOBECCA5FHQD43KAK2QMJD&iid=312033a6-e736-4227-bacb-71a010869975.MOBECCA5FHQD43KA.SEARCH
# Samsung Galaxy On5 (Gold, 8 GB)  (1.5 GB RAM)
# 4.2 ★100,024 Ratings & 15,483 Reviews
# ₹6,690₹8,99025% off
# Special Discount ends in few hours
# 1.5 GB RAM | 8 GB ROM | Expandable Upto 128 GB
# 5 inch HD Display
# 8MP Rear Camera | 5MP Front Camera
# 2600 mAh Li-Ion Battery
# Exynos 3475 Processor
# EMI starting from ₹325/month
# In The BoxHandset, Stereo Headset, Travel Adaptor, Data Cable, Product User Guide, Battery
# Model NumberSM-G550FZKDINS/SM-G550FZDDINS
# ...

# %%
import os
from bs4 import BeautifulSoup
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv
# writefile = 'nnnnnn.csv'
# blueb = open(writefile, 'w')
# wr = csv.writer(blueb)
# wr.writerow(["f1","f2","f3","f4","f5","f6","f7","f8","f9"])

sad1='/search?q=mobile&otracker=start&as-show=off&as=off'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'https://www.flipkart.com'+sad1
#     print (url)
    u = urlopen(url)
    try:
        html = u.read().decode('utf-8')
    finally:
        u.close()
    soup = BeautifulSoup(html, "html.parser")
    aa=soup.find('div',{'class':"_2SxMvQ"})
    for link in aa.select('a'):
        sad = link.get('href')
#         print(sad)
        sad4='https://www.flipkart.com'+sad
        n = urlopen(sad4)
        print(sad4)
# #         f1=sad4
        try:
            html1 = n.read().decode('utf-8')
        finally:
            n.close()
        soup2 = BeautifulSoup(html1,"html.parser")
        mt=soup2.find('div',{'class':"_2UDlNd"})
        for items in soup2.find('div',{'class':"_1MVZfW"}):
            print(items.text)
#             f2=items.text
        if(soup2.find('li',{'class':"_2-riNZ"})):
            ab=soup2.find('li',{'class':"_2-riNZ"})
            print(ab.text)
#         f3=ab.text
            for item in ab.find_next_siblings():
                print(item.text)
#             f4=item.text
        if(soup2.find('div',{'class':"_3dJKzj"})):
            for an in soup2.find('div',{'class':"_3dJKzj"}):
                print(an.text)
#             f5=an.text
        ap= soup2.find('li',{'class':"puBqcQ"})
        print(ap.text)
#         f6=ap.text
        for item in an.find_next_siblings():
            print(item.text)
            f7=item.text
        ad= soup2.find('li',{'class':"_1KuY3T row"})
        print(ad.text)
        f8=ad.text
        for item in ad.find_next_siblings():
            print(item.text)
            f9=item.text
        i=i+1
        print(i)
    if(soup.find('div',text="Next")):
        an=soup.find('div',text="Next")
        for na in an.select('a'):
            sad1 = na.get('href')
#             print(sad1)
# Out:
# https://www.flipkart.com/moto-e4-plus-iron-gray-32-gb/p/itmevqynuz4fwxca?pid=MOBEU9WRZHNDJANR&srno=s_1_1&otracker=search&lid=LSTMOBEU9WRZHNDJANRZEB2S1&iid=e0a21c5d-bb66-40ca-beae-75a2116ac0d8.MOBEU9WRZHNDJANR.SEARCH&qH=532c28d5412dd75b
# Moto E4 Plus (Iron Gray, 32 GB)  (3 GB RAM)#OnlyOnFlipkart
# 4 ★63,798 Ratings & 16,619 Reviews
# ₹9,999
#
# 3 GB RAM | 32 GB ROM | Expandable Upto 128 GB
# 5.5 inch HD Display
# 13MP Rear Camera | 5MP Front Camera
# 5000 mAh Li-Ion Polymer Battery
# MediaTek MTK6737 1.3GHz Processor
# Android Nougat 7.1.1 | Stock Android Version
# Front Fingerprint Sensor
# Dedicated SD Card Slot
# Front and Rear Flash
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-58e67961fcff> in <module>()
#      53 #             f5=an.text
#      54         ap= soup2.find('li',{'class':"puBqcQ"})
# ---> 55         print(ap.text)
# ...

# %%
import os
from bs4 import BeautifulSoup
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv
# writefile = 'nnnnnn.csv'
# blueb = open(writefile, 'w')
# wr = csv.writer(blueb)
# wr.writerow(["f1","f2","f3","f4","f5","f6","f7","f8","f9"])

sad1='/search?as=off&as-show=off&otracker=start&page=280&q=mobile&viewType=list'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'https://www.flipkart.com'+sad1
#     print (url)
    u = urlopen(url)
    try:
        html = u.read().decode('utf-8')
    finally:
        u.close()
    soup = BeautifulSoup(html, "html.parser")
    aa=soup.find('div',{'class':"_2SxMvQ"})
    for link in aa.select('a'):
        sad = link.get('href')
#         print(sad)
        sad4='https://www.flipkart.com'+sad
#         n = urlopen(sad4)
        print(sad4)
# #         f1=sad4
#         try:
#             html1 = n.read().decode('utf-8')
#         finally:
#             n.close()
#         soup2 = BeautifulSoup(html1,"html.parser")
#         mt=soup2.find('div',{'class':"_2UDlNd"})
#         for items in soup2.find('div',{'class':"_1MVZfW"}):
#             print(items.text)
# #             f2=items.text
#         ab=soup2.find('li',{'class':"_2-riNZ"})
#         print(ab.text)
# #         f3=ab.text
#         for item in ab.find_next_siblings():
#             print(item.text)
# #             f4=item.text
#         for an in soup2.find('div',{'class':"_3dJKzj"}):
#             print(an.text)
# #             f5=an.text
#         ap= soup2.find('li',{'class':"puBqcQ"})
#         print(ap.text)
# #         f6=ap.text
#         for item in an.find_next_siblings():
#             print(item.text)
#             f7=item.text
#         ad= soup2.find('li',{'class':"_1KuY3T row"})
#         print(ad.text)
#         f8=ad.text
#         for item in ad.find_next_siblings():
#             print(item.text)
#             f9=item.text
        i=i+1
        print(i)
    if(soup.find('div',text="Next")):
        an=soup.find('div',text="Next")
        for na in an.select('a'):
            sad1 = na.get('href')
#             print(sad1)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-8-efe7810a5e13> in <module>()
#      18     url = 'https://www.flipkart.com'+sad1
#      19 #     print (url)
# ---> 20     u = urlopen(url)
#      21     try:
#      22         html = u.read().decode('utf-8')
#
# C:\Users\smc46\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\Users\smc46\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ...
