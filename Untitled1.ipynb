# %%
import pandas as pd
df = pd.read_excel("C:\Users\smc46\Desktop\Cleaning data.xlsx")
print df.head(5)
# Out:
#       id  Page1  state     district  Gender    AGE       Q4        Q5        \
# 0  31049      1        19       188         1        22         2         5
# 1  31040      1         8        52         1        23         1         3
# 2  31037      1        32       422         1        19         1         4
# 3  31035      1        27       310         1        25         1         7
# 4  31032      1        19       190         1        22         2         5
#
#    Q6        Q7            ...        Q110_11       Q110_12       \
# 0         1       5.0      ...                 NaN           NaN
# 1        17       NaN      ...                 NaN           NaN
# 2         8       NaN      ...                 NaN           NaN
# 3         8       NaN      ...                 1.0           2.0
# 4         1       5.0      ...                 2.0           2.0
#
#    Q110_13       Q110_14       Q110_15       Q110_16       Q110_17       \
# ...

# %%
printdf.sort(['Product','Sales'], ascending=[True, False])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7c56e56079e0> in <module>()
# ----> 1 data.loc[:['Q6      ','Q7      ']]
#
# NameError: name 'data' is not defined

# %%
x=df.loc[:,['Q6      ','Q7      ']]
print x
# Out:
#        Q6        Q7
# 0             1       5.0
# 1            17       NaN
# 2             8       NaN
# 3             8       NaN
# 4             1       5.0
# 5            17       7.0
# 6             1       6.0
# 7            15       NaN
# 8             1       7.0
# 9             8       NaN
# 10            1       6.0
# 11           11       NaN
# 12            6       NaN
# 13            1       6.0
# 14            5       7.0
# 15           13       NaN
# 16            1       3.0
# 17            6       NaN
# 18            3       NaN
# 19            1       NaN
# 20            1       5.0
# 21            1       7.0
# 22            5       6.0
# 23            1       7.0
# 24           17       NaN
# 25            7       NaN
# 26            1       5.0
# 27            2       NaN
# 28            1       NaN
# 29            1       NaN
# ...         ...       ...
# 10581         5       7.0
# 10582         1       NaN
# 10583         2       6.0
# ...

# %%
data.loc[:['Gender  ']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4dc80551da2f> in <module>()
# ----> 1 data.loc[:['Gender  ']]
#
# NameError: name 'data' is not defined

# %%
df.lc[:['Gender  ']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-1dbff6a7bf11> in <module>()
# ----> 1 df.loc[:['Gender  ']]
#
# C:\Users\smc46\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in __getitem__(self, key)
#    1294             return self._getitem_tuple(key)
#    1295         else:
# -> 1296             return self._getitem_axis(key, axis=0)
#    1297
#    1298     def _getitem_axis(self, key, axis=0):
#
# C:\Users\smc46\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _getitem_axis(self, key, axis)
#    1435         if isinstance(key, slice):
#    1436             self._has_valid_type(key, axis)
# -> 1437             return self._get_slice_axis(key, axis=axis)
#    1438         elif is_bool_indexer(key):
#    1439             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
x.sort(['Q6      '], ascending=[True])
# Out:
# C:\Users\smc46\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#        Q6        Q7
# 0             1       5.0
# 6179          1       NaN
# 6178          1       NaN
# 6177          1       5.0
# 6175          1       NaN
# 6174          1       NaN
# 6172          1       7.0
# 6169          1       4.0
# 6168          1       NaN
# 6167          1       NaN
# 6166          1       NaN
# 6165          1       6.0
# 6164          1       3.0
# 6163          1       1.0
# 6180          1       5.0
# 6162          1       NaN
# 6157          1       7.0
# 6154          1       7.0
# 6153          1       7.0
# 6152          1       4.0
# 6150          1       NaN
# 6148          1       5.0
# 6145          1       7.0
# 6144          1       6.0
# 6142          1       NaN
# 6137          1       6.0
# 6136          1       NaN
# 6133          1       NaN
# ...
