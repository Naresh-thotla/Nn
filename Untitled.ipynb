# %%
import pandas as pd
data=pd.read_excel("C:\Users\smc46\Desktop\python\Cleaning data.xlsx")
print(data)
# Out:
#           id  Page1  state     district  Gender    AGE       Q4        \
# 0      31049      1        19       188         1        22         2
# 1      31040      1         8        52         1        23         1
# 2      31037      1        32       422         1        19         1
# 3      31035      1        27       310         1        25         1
# 4      31032      1        19       190         1        22         2
# 5      31031      1        24       276         1        15         2
# 6      31030      1        22       234         1        24         2
# 7      31024      1        29       389         1        21         1
# 8      31021      1        10       148         1        16         2
# 9      31016      1         9        94         1        24         1
# 10     31014      1        32       419         1        20         2
# 11     31010      1        30       415         1        19         1
# ...

# %%
import pandas as pd
labels=['Gender  ','AGE     ']
data=pd.read_excel("C:\Users\smc46\Desktop\python\Cleaning data.xlsx",lables=lables)
print(data)
# Out:
#   File "<ipython-input-2-00ecfb14d1cb>", line 3
#     data=pd.read_excel("C:\Users\smc46\Desktop\python\Cleaning data.xlsx",lables=lables)
#                       ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
