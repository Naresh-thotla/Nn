# %%
import os
from bs4 import BeautifulSoup
import unidecode
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv
import re
writefile = 'flipkart.csv'
blueb = open(writefile, 'w')
wr = csv.writer(blueb)
wr.writerow(["f1","f2"])

sad1='/mobiles/samsung~brand/pr?count=40&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&p%5B%5D=sort%3Dpopularity&page=1&sid=tyy%2F4io&viewType=list'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'https://www.flipkart.com'+sad1
    print (url)
    u = urlopen(url)
    try:
        html = u.read().decode('utf-8')
    finally:
        u.close()
    soup = BeautifulSoup(html, "html.parser")
    aa=soup.find('div',{'class':"_2SxMvQ"})
    for link in aa.select('a'):
        sad = link.get('href')
#         print(sad)
        sad4='https://www.flipkart.com'+sad
        n = urlopen(sad4)
        print(sad4)
        f1=sad4
        try:
            html1 = n.read().decode('utf-8')
        finally:
            n.close()
        soup2 = BeautifulSoup(html1,"html.parser")
        if(soup2.find('div',{'class':"_2UDlNd"})):
            for items in soup2.find('div',{'class':"_2UDlNd"}):
                print(items.text)
        if(soup2.find('div',{'class':"_1uv9Cb"})):
            for items in soup2.find('div',{'class':"_1uv9Cb"}):
#             if (items!="react"):
                print(items.text)
        if(soup2.find('div',{'class':"_3nSGUy"})):
            for items in soup2.find('div',{'class':"_3nSGUy"}):
                print(items.text)
# #                 f3=items.text
        if(soup2.find('div',{'class':"_2sVT0Y"})):
            for items in soup2.find('div',{'class':"_2sVT0Y"}):
                print(items.text)
#                 f4=items.text
        if(soup2.find('div',{'class':"_2KVF1P"})):
            for items in soup2.find('div',{'class':"_2KVF1P"}):
                print(items.text)
#                 f5=items.text
        if(soup2.find('div',{'class':"_34wn58"})):
            for items in soup2.find('div',{'class':"_34wn58"}):
                print(items.text)
#                 f6=items.text
        if(soup2.find('div',{'class':"_2Kp3n6"})):
            for items in soup2.find('div',{'class':"_2Kp3n6"}):
                print(items.text)
#                 f7=items.text
#         wr.writerow([f1])
        i=i+1
        print(i)
        
    if(soup.find('div',text="Next")):
        an=soup.find('div',text="Next")
        for na in an.select('a'):
            sad1 = na.get('href')
            print(sad1)
blueb.close()
# Out:
# https://www.flipkart.com/mobiles/samsung~brand/pr?count=40&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&p%5B%5D=sort%3Dpopularity&page=1&sid=tyy%2F4io&viewType=list
# https://www.flipkart.com/samsung-galaxy-on5-gold-8-gb/p/itmedhx3uy3qsfks?pid=MOBECCA5FHQD43KA&srno=b_1_1&otracker=clp_metro_expandable_1_mobil-categ-fc059_Samsung_mobiles_8YU2PLHN2B_wp2&lid=LSTMOBECCA5FHQD43KAK2QMJD&fm=organic&iid=978aa308-c893-4864-8772-f923cc23ed80.MOBECCA5FHQD43KA.SEARCH
# Samsung Galaxy On5 (Gold, 8 GB)  (1.5 GB Ram)
# ₹6,990
# ₹8,990
# 22% off
# Special PriceFlat ₹2,000 Off On Samsung On5T&CTry Phone Checkup- Get up to 12% more on exchange! (Applicable only on Flipkart App)
# Warranty
# 1 Year for Mobile & 6 Months for Accessories
# Highlights1.5 GB RAM | 8 GB ROM | Expandable Upto 128 GB5 inch HD Display8MP Rear Camera | 5MP Front Camera2600 mAh Li-Ion BatteryExynos 3475 Quad Core 1.3GHz Processor
# ...

# %%
import os
from bs4 import BeautifulSoup
# import urllib2/
import requests
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv
writefile = 'amazon.csv'
blueb = open(writefile, 'w')
wr = csv.writer(blueb)
wr.writerow(["f1","f2","f3"])

sad1='/s/ref=sr_nr_p_89_3?fst=as%3Aoff&rh=n%3A976419031%2Cn%3A%21976420031%2Cn%3A1389401031%2Cn%3A1389432031%2Cp_98%3A10440597031%2Cp_89%3ASamsung&bbn=1389432031&ie=UTF8&qid=1503902532&rnid=3837712031'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'http://www.amazon.in'+sad1
    print (url)
    u = requests.get(url)
    html =u.content
#     try:
#         html = html.read().decode('utf-8')
#     finally:
#         u.close()
    soup = BeautifulSoup(html, "html.parser")
    aa=soup.find('div',{'id':"centerMinus"})
    for lin in aa.find_all('div',{'class':"a-row a-spacing-mini"}):
        if(lin.find_all('a',{'class':"a-link-normal s-access-detail-page  s-color-twister-title-link a-text-normal"})):
            for link in lin.select('a'):
                sad = link.get('href')
#                 print(sad)
#                 print(link.text)
                f1=sad
                f2=link.text
        if(lin.find('span',{'class':"a-size-base a-color-price s-price a-text-bold"})):
            for content in lin.find('span',{'class':"a-size-base a-color-price s-price a-text-bold"}):
                print(content)
            f3=content
#         print(lin.text)
            wr.writerow([f1,f2,f3])
            i=i+1
            print(i)
        
    if(soup.find('span',{'class':"pagnRA"})):
        an=soup.find('span',{'class':"pagnRA"})
#         print(an)
        for na in an.select('a'):
            sad1 = na.get('href')
# #             print(sad1)
blueb.close()
# Out:
# http://www.amazon.in/s/ref=sr_nr_p_89_3?fst=as%3Aoff&rh=n%3A976419031%2Cn%3A%21976420031%2Cn%3A1389401031%2Cn%3A1389432031%2Cp_98%3A10440597031%2Cp_89%3ASamsung&bbn=1389432031&ie=UTF8&qid=1503902532&rnid=3837712031
# <span class="currencyINR">  </span>
# 7,490
# 1
# <span class="currencyINR">  </span>
# 8,990
# 2
# <span class="currencyINR">  </span>
# 1,660
# 3
# <span class="currencyINR">  </span>
# 1,660
# 4
# <span class="currencyINR">  </span>
# 12,090
# 5
# <span class="currencyINR">  </span>
# 7,490
# 6
# <span class="currencyINR">  </span>
# 1,200
# 7
# <span class="currencyINR">  </span>
# 1,200
# 8
# <span class="currencyINR">  </span>
# 1,410
# 9
# <span class="currencyINR">  </span>
# 17,900
# 10
# <span class="currencyINR">  </span>
# 12,090
# 11
# <span class="currencyINR">  </span>
# 17,900
# 12
# <span class="currencyINR">  </span>
# 1,200
# 13
# <span class="currencyINR">  </span>
# 3,190
# 14
# <span class="currencyINR">  </span>
# 1,990
# 15
# ...

# %%
import os
from bs4 import BeautifulSoup
# import urllib2/
import requests
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv

sad1='/s/ref=lp_1389432031_nr_p_98_0?fst=as%3Aoff&rh=n%3A976419031%2Cn%3A%21976420031%2Cn%3A1389401031%2Cn%3A1389432031%2Cp_98%3A10440597031&bbn=1389432031&ie=UTF8&qid=1502377116&rnid=10440596031'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'http://www.amazon.in'+sad1
    print (url)
    u = requests.get(url)
    html =u.content
    soup = BeautifulSoup(html, "html.parser")
    aa=soup.find('div',{'id':"centerMinus"})
#     for lin in aa.find_all('div',{'class':"a-row a-spacing-mini"}):
#         if(lin.find_all('a',{'class':"a-link-normal s-access-detail-page  s-color-twister-title-link a-text-normal"})):
#             for link in lin.select('a'):
#                 sad = link.get('href')
#             print(sad)
# # #         i=i+1
# #         print(i)
#             n = requests.get(sad)
#             html1=n.content
#             soup2 = BeautifulSoup(html1,"html.parser")
#             i=i+1
#             print(i)
#             naresh=soup2.find('div',{'id':"centerCol"})
#             if(naresh.find('table',{'class':"a-lineitem"})):
#                 for items in naresh.find('table',{'class':"a-lineitem"}):
#                     print(items.text)
    
    
    
    
    if(soup.find('span',{'class':"pagnRA"})):
        an=soup.find('span',{'class':"pagnRA"})
        for na in an.select('a'):
            sad1 = na.get('href')
#             print(sad1)
# Out:
# http://www.amazon.in/s/ref=lp_1389432031_nr_p_98_0?fst=as%3Aoff&rh=n%3A976419031%2Cn%3A%21976420031%2Cn%3A1389401031%2Cn%3A1389432031%2Cp_98%3A10440597031&bbn=1389432031&ie=UTF8&qid=1502377116&rnid=10440596031
# http://www.amazon.in/Smartphones-Basic-Mobiles-Fulfilled-by-Amazon/s?ie=UTF8&page=2&rh=n%3A1389432031%2Cp_98%3A10440597031
# http://www.amazon.in/Smartphones-Basic-Mobiles-Fulfilled-by-Amazon/s?ie=UTF8&page=3&rh=n%3A1389432031%2Cp_98%3A10440597031
# http://www.amazon.in/Smartphones-Basic-Mobiles-Fulfilled-by-Amazon/s?ie=UTF8&page=4&rh=n%3A1389432031%2Cp_98%3A10440597031
# http://www.amazon.in/Smartphones-Basic-Mobiles-Fulfilled-by-Amazon/s?ie=UTF8&page=5&rh=n%3A1389432031%2Cp_98%3A10440597031
# http://www.amazon.in/Smartphones-Basic-Mobiles-Fulfilled-by-Amazon/s?ie=UTF8&page=6&rh=n%3A1389432031%2Cp_98%3A10440597031
# http://www.amazon.in/Smartphones-Basic-Mobiles-Fulfilled-by-Amazon/s?ie=UTF8&page=7&rh=n%3A1389432031%2Cp_98%3A10440597031
# ...

# %%
import os
from bs4 import BeautifulSoup
# import urllib2/
import requests
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv
from selenium import webdriver
from selenium.webdriver.common.keys import Keys


sad1='/search?keyword=mobile&santizedKeyword=mobile&catId=0&categoryId=175&suggested=false&vertical=p&noOfResults=20&searchState=previousRequest%3Dtrue%7CserviceabilityUsed%3Dfalse%7CfilterState%3Dnull&clickSrc=searchOnSubCat&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy&q=Brand%3ASamsung%7C#bcrumbSearch:mobile'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'https://www.snapdeal.com'+sad1
    print (url)
    payload = {"count":100}
    u = requests.get(url,data=payload)
    html =u.content
    soup = BeautifulSoup(html, "html.parser")
    aa=soup.find('div',{'class':"product-row js-product-list centerCardAfterLoadWidgets dp-click-widgets"})
    for link in aa.find_all('div',{'class':"product-desc-rating "}):
        for sad in link.select('a'):
            sad2=sad.get('href')
            print(sad2)
            pt=sad.find('p',{'class':"product-title "})
            pr=sad.find('span',{'class':"lfloat product-price"})
            print(pt.text)
            print(pr.text)
#         lin=link()
#         print(link.text)
        i=i+1
        print(i)
# Out:
# https://www.snapdeal.com/search?keyword=mobile&santizedKeyword=mobile&catId=0&categoryId=175&suggested=false&vertical=p&noOfResults=20&searchState=previousRequest%3Dtrue%7CserviceabilityUsed%3Dfalse%7CfilterState%3Dnull&clickSrc=searchOnSubCat&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy&q=Brand%3ASamsung%7C#bcrumbSearch:mobile
# https://www.snapdeal.com/product/samsung-galaxy-j7-prime-32gb/5764608145562168886
# Samsung Galaxy J7 Prime (3GB, 32GB)
# Rs.  15,900
# 1
# https://www.snapdeal.com/product/samsung-z2-8gb-black/5764608156634832250
# Samsung Tizen Z2 (OS) (8GB) voLTE
# Rs.  4,650
# 2
# https://www.snapdeal.com/product/samsung-z2-8gb-black/6917529661241679226
# Samsung Tizen Z2 (OS) (8GB) voLTE
# Rs.  4,650
# 3
# https://www.snapdeal.com/product/samsung-galaxy-j7-prime-32gb/6917529650169015862
# Samsung Galaxy J7 Prime (3GB, 32GB)
# Rs.  15,999
# 4
# ...

# %%
import os
from bs4 import BeautifulSoup
# import urllib2/
import requests
# Python 3.x
from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin
import io, json
import csv
from selenium import webdriver
from selenium.webdriver.common.keys import Keys


sad1='/search?keyword=mobile&santizedKeyword=mobile&catId=0&categoryId=175&suggested=false&vertical=p&noOfResults=20&searchState=previousRequest%3Dtrue%7CserviceabilityUsed%3Dfalse%7CfilterState%3Dnull&clickSrc=searchOnSubCat&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy&q=Brand%3ASamsung%7C#bcrumbSearch:mobile'
sad3='a'
i=0
while(sad3!=sad1):
    sad3= sad1
    url = 'https://www.snapdeal.com'+sad1
    driver = webdriver.Chrome()
    driver.get("https://www.snapdeal.com/search?keyword=mobile&santizedKeyword=mobile&catId=0&categoryId=175&suggested=false&vertical=p&noOfResults=20&searchState=previousRequest%3Dtrue%7CserviceabilityUsed%3Dfalse%7CfilterState%3Dnull&clickSrc=searchOnSubCat&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy&q=Brand%3ASamsung%7C#bcrumbSearch:mobile")
    elem = driver.find_element_by_class_name("product-row js-product-list centerCardAfterLoadWidgets dp-click-widgets")
    elem.getText()
    
driver.close()
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# <ipython-input-1-2ba40a5176d0> in <module>()
#      20     driver = webdriver.Chrome()
#      21     driver.get("https://www.snapdeal.com/search?keyword=mobile&santizedKeyword=mobile&catId=0&categoryId=175&suggested=false&vertical=p&noOfResults=20&searchState=previousRequest%3Dtrue%7CserviceabilityUsed%3Dfalse%7CfilterState%3Dnull&clickSrc=searchOnSubCat&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy&q=Brand%3ASamsung%7C#bcrumbSearch:mobile")
# ---> 22     elem = driver.find_element_by_class_name("product-row js-product-list centerCardAfterLoadWidgets dp-click-widgets")
#      23     elem.getText()
#      24
#
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os
path=r'C:\Users\smc46\Anaconda3\Lib\site-packages\selenium\webdriver\chrome\chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get("https://www.snapdeal.com/search?keyword=mobile&santizedKeyword=mobile&catId=0&categoryId=175&suggested=false&vertical=p&noOfResults=20&searchState=previousRequest%3Dtrue%7CserviceabilityUsed%3Dfalse%7CfilterState%3Dnull&clickSrc=searchOnSubCat&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy&q=Brand%3ASamsung%7C#bcrumbSearch:mobile")
# assert "Python" in driver.title
# driver.find_element_by_xpath("//*[@id='pagination-txt']")
posts = driver.find_elements_by_class_name("product-desc-rating ")
i=0
for post in posts:
    
    print(post.text)
    i=i+1
    print(i)

# elem.send_keys("pycon")
# elem.send_keys(Keys.RETURN)
# assert "No results found." not in driver.page_source
# Out:
# Samsung J7 Max 32GB
# Rs. 19,150
# Rs. 17,900
# 7% Off
# (63)
# 1
# Samsung Tizen Z2 (OS) (8GB) voLTE
# Rs. 4,990
# Rs. 4,590
# 8% Off
# (1136)
# 2
# Samsung Tizen Z2 (OS) (8GB) voLTE
# Rs. 4,990
# Rs. 4,590
# 8% Off
# (1136)
# 3
# Samsung Galaxy J7 Prime (3GB, 32GB)
# Rs. 18,100
# Rs. 15,900
# 12% Off
# (154)
# 4
# Samsung J7 Max 32GB
# Rs. 19,150
# Rs. 17,900
# 7% Off
# (63)
# 5
# Samsung Metro XL (White )
# Rs. 3,400
# Rs. 3,379
# 1% Off
# (445)
# 6
# Samsung Guru E1200 (White)
# Rs. 1,270
# Rs. 1,268
# (1431)
# 7
# Samsung Galaxy J7 Prime (3GB, 32GB)
# Rs. 18,200
# Rs. 16,199
# 11% Off
# (154)
# 8
# Samsung Galaxy J5 Prime (16GB)
# Rs. 15,990
# Rs. 11,750
# 27% Off
# (233)
# 9
# Samsung Galaxy J5 Prime (16GB)
# Rs. 15,990
# Rs. 11,750
# 27% Off
# (233)
# 10
# Samsung Galaxy J7 Pro (3GB, 64GB)
# Rs. 25,000
# Rs. 22,999
# 8% Off
# (6)
# 11
# Samsung Galaxy J2 Pro (16 GB)
# Rs. 9,890
# Rs. 9,790
# 1% Off
# (18404)
# 12
# Samsung Galaxy J2 Pro (16 GB)
# Rs. 10,900
# Rs. 9,090
# ...

# %%
import time

from selenium import webdriver
from selenium.webdriver.common.keys import Keys

browser = webdriver.Chrome()

browser.get("https://www.snapdeal.com/search?keyword=mobile&santizedKeyword=mobile&catId=0&categoryId=175&suggested=false&vertical=p&noOfResults=20&searchState=previousRequest%3Dtrue%7CserviceabilityUsed%3Dfalse%7CfilterState%3Dnull&clickSrc=searchOnSubCat&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy&q=Brand%3ASamsung%7C#bcrumbSearch:mobile")
time.sleep(1)

# elem = browser.find_element_by_tag_name("body")

# no_of_pagedowns = 20

# while no_of_pagedowns:
#     elem.send_keys(Keys.PAGE_DOWN)
#     time.sleep(0.2)
#     no_of_pagedowns-=1

elems = browser.find_element_by_tag_name("html")
# print(elems)
n=200
i=0
while n:
    elems.send_keys(Keys.PAGE_DOWN)
    time.sleep(0.1)
#     if(browser.find_element_by_xpath("//*[@id='see-more-products']")):
#        (browser.find_element_by_xpath("//*[@id='see-more-products']")).click()
#        n=200
#     if(browser.find_element_by_xpath("//*[@id='content_wrapper']/div[7]/div[2]/div/div[10]/div[2]")
#        browser.find_element_by_xpath("//*[@id='content_wrapper']/div[7]/div[2]/div/div[10]/div[2]".click()
    n=n-1
html=browser.page_source
soup = BeautifulSoup(html, "html.parser")
aa=soup.find('div',{'class':"product-row js-product-list centerCardAfterLoadWidgets dp-click-widgets"})
for link in aa.find_all('div',{'class':"product-desc-rating "}):
    for sad in link.select('a'):
        sad2=sad.get('href')
        print(sad2)
        pt=sad.find('p',{'class':"product-title "})
        pr=sad.find('span',{'class':"lfloat product-price"})
        print(pt.text)
        print(pr.text)
#         lin=link()
#         print(link.text)
    i=i+1
    print(i)
# Out:
# https://www.snapdeal.com/product/samsung-j7-max-32gb/6917529675993506119#bcrumbSearch:mobile|bcrumbLabelId:175
# Samsung J7 Max 32GB
# Rs.  17,900
# 1
# https://www.snapdeal.com/product/samsung-galaxy-j7-prime-32gb/5764608145562168886#bcrumbSearch:mobile|bcrumbLabelId:175
# Samsung Galaxy J7 Prime (3GB, 32GB)
# Rs.  15,900
# 2
# https://www.snapdeal.com/product/samsung-j7-max-32gb/5764608171386659143#bcrumbSearch:mobile|bcrumbLabelId:175
# Samsung J7 Max 32GB
# Rs.  17,900
# 3
# https://www.snapdeal.com/product/samsung-b355e-white-below-256/638677456537#bcrumbSearch:mobile|bcrumbLabelId:175
# Samsung Metro XL (White )
# Rs.  3,375
# 4
# https://www.snapdeal.com/product/samsung-galaxy-j7-prime-32gb/6917529650169015862#bcrumbSearch:mobile|bcrumbLabelId:175
# Samsung Galaxy J7 Prime (3GB, 32GB)
# Rs.  16,199
# 5
# https://www.snapdeal.com/product/samsung-galaxy-j5-prime-16gb/5764608154239857469#bcrumbSearch:mobile|bcrumbLabelId:175
# Samsung Galaxy J5 Prime (16GB)
# Rs.  11,750
# 6
# ...
